# %% [markdown]
# <ul> Deep Learning Image Registration:
#
#     <li>
#         <a href=http://ieeexplore.ieee.org/xpl/articleDetails.jsp?reload=true&arnumber=7314894>Scalable High-Performance Image Registration Framework by Unsupervised Deep Feature Representations Learning</a>
#     </li>
#
#     <li>
#         <a href=https://www.cir.meduniwien.ac.at/assets/Uploads/Masterthesis-SeeboeckPhilipp-Version28-03-2015.pdf>Deep Learning in Medical Image Analysis</a>
#     </li>
#
#     <li>
#         <a href=http://vis-www.cs.umass.edu/papers/nips2012_deep_congealing.pdf>Learning to Align from Scratch</a>
#     </li>
#
#     <li>
#         <a href=http://stat.fsu.edu/~abarbu/papers/MICCAI%20Tutorial%20-%20Deep%20Learning%20(2014-09-14)_by%20Dinggang%20Shen.pdf>Deep Learning in Medical Image Analysis (IDEA Research Lab)(PDF Presentation)</a>
#     </li>
#         <li>
#         <a href=http://www.ncbi.nlm.nih.gov/pubmed/24579196>Unsupervised deep feature learning for deformable registration of MR brain images.</a>
#     </li>
#         <li>
#         <a href=http://www.ncbi.nlm.nih.gov/pubmed/26120356>Deep Adaptive Log-Demons: Diffeomorphic Image Registration with Very Large Deformations.</a>
#     </li>
#
# </ul>
#
# <ul> Image Registration:
#     <li>
#         <a href=https://github.com/Vaa3D>Vaa3D</a>
#     </li>
#
#
#     <li>
#         <a href=http://www.sciencedirect.com/science/article/pii/S111086651500047X>Current trends in medical image registration and fusion</a>
#     </li>
#
#     <li>
#         <a href=http://www.nature.com/nmeth/journal/v12/n4/full/nmeth.3296.html>Image fusion of mass spectrometry and microscopy: a multimodality paradigm for molecular tissue mapping</a>
#     </li>
#     <li>
#         <a href=http://www.sciencedirect.com/science/article/pii/S0010482516300774>Medical image registration using sparse coding of image patches</a>
#     </li>
#
#     <li>
#         <a href=http://link.springer.com/chapter/10.1007/978-81-322-2671-0_40>3D Multimodal Medical Image Fusion and Evaluation of Diseases</a>
#     </li>
#
#
#         <li>
#         <a href=http://www.ncbi.nlm.nih.gov/pubmed/27347565>Multimodal fusion of brain imaging data: A key to finding the missing link(s) in complex mental illness.</a>
#     </li>
#
#
#     <li>
#         <a href=http://wbir2016.doc.ic.ac.uk> WBIR 2016 -7th International Workshop on Biomedical Image Registration – July 1, Las Vegas, Nevada, USA </a>
#     </li>
#
# </ul>
#
# <ul> Big Data:
#     <li>
#         <a href=https://databricks.com/blog/2016/01/25/deep-learning-with-apache-spark-and-tensorflow.html>Deep Learning with Apache-Spark and Tensorflow</a>
#     </li>
#
#     <li>
#         <a href=http://www.slideshare.net/continuumio/gpu-computing-with-apache-spark-and-python>GPU Computing with Apache Spark and Python with Image Registration Example</a>
#     </li>
#     <li>
#         <a href=http://kmader.github.io/Quantitative-Big-Imaging-2016/> Quantitative Big Imaging Course (2016) </a>
#     </li>
#     <li>
#         <a href=http://kmader.github.io/Quantitative-Big-Imaging-Course/ > Quantitative Big Imaging Course </a>
#     </li>
#
#     <li>
#         <a href=https://www.continuum.io/blog/developer-blog/using-anaconda-pyspark-distributed-language-processing-hadoop-cluster> Using Anaconda with PySpark for Distributed Language Processing on a Hadoop Cluster</a>
#     </li>
#     <li>
#         <a href=http://www.infoworld.com/article/2683729/hadoop/10-ways-to-query-hadoop-with-sql.html>10 Ways to query hadoop with sql- note Spark SQL</a>
#     </li>
#     <li>
#         <a href=https://docs.python.org/2/library/multiprocessing.html> Multiprocessing in Python </a>
#     </li>
#     <li>
#     <a href=http://adilmoujahid.com/posts/2015/01/interactive-data-visualization-d3-dc-python-mongodb/ > Interactive Data Visualization with D3, Python and MongoDB </a>
#     </li>
#
# </ul>
#
# <ul> Libraries:
#
#     <li>
#         <a href=https://github.com/josephmisiti/awesome-machine-learning#julia-data-analysis/ >Libraries for Julia data analysis</a>
#     </li>
#
#     <li>
#         <a href=http://deeplearning4j.org>DEEPLEARNING4J: Open-source, distributed, deep-learning library for the JVM</a>
#     </li>
#
#
#
#     <li>
#         <a href=https://www.kaggle.com/c/street-view-getting-started-with-julia> Getting started with Julia competition</a>
#     </li>
#
#     <li>
#         <a href=https://github.com/JuliaQuant>Quantitative finance in Julia</a>
#     </li>
# </ul>
#
# <ul> Quant Finance
#     <li>
#         <a href=http://www.euclidean.com/deep-learning-and-value-investing/ > Deep learning and value investing </a>
#     </li>
# </ul>
# <ul> General Tutorials:
#
#     <li>
#         <a href='https://github.com/chrislgarry/awesome-machine-learning'>Awesome Machine Learning</a>
#     </li>
#
#     <li>
#         <a href=http://ujjwalkarn.github.io/Machine-Learning-Tutorials/>Machine Learning Tutorials</a>
#     </li>
#
#     <li>
#         <a href=https://github.com/jakevdp/sklearn_tutorial>Scikit-learn Tutorial</a>
#     </li>
#
#     <li>
#         <a href=http://deepdish.io/2015/04/28/creating-lmdb-in-python/>Creating an LMDB database in Python</a>
#     </li>
#
#     <li>
#         <a href=https://github.com/ipython/ipython/wiki/A-gallery-of-interesting-IPython-Notebooks#introductory-tutorials>A gallery of interesting IPython Notebooks</a>
#     </li>
#
#     <li>
#         <a href=http://jrjohansson.github.io/numericalpython.html/ >Numerical Python</a>
#     </li>
#
# </ul>
#
# <ul> IDE/Notebook Tips and Tricks:
#
#     <li>
#         <a href=https://community.hortonworks.com/content/idea/43020/setting-up-your-spark-spark-sql-development-enviro.html>Setting up your spark/spark-sql development environment in PyCharm</a>
#     </li>
#
#     <li>
#         <a href=http://stackoverflow.com/questions/34685905/how-to-link-pycharm-with-pyspark>How to link pycharm with pyspark</a>
#     </li>
#
#     <li>
#         <a href=http://blog.booleanbiotech.com/ipython_notebook_tips.html> IPython Notebook Tips</a>
#     </li>
#
#     <li>
#         <a href=http://ozkatz.github.io/better-python-apis.html/ >Better Python APIs</a>
#     </li>
#
#     <li>
#         <a href=http://numba.pydata.org/ >Numba just in time compilation</a>
#     </li>
#
#
#
# </ul>
#
# <ul> General:
#
#     <li>
#         <a href=http://null-byte.wonderhowto.com/how-to/> Null-byte How-Tos </a>
#     </li>
#     <li>
#         <a hfre=https://www.twilio.com/> Twilio - send SMS from python</a>
#     </li>
#     <li>
#         <a href=https://d3js.org/>Data Visualizations and D3.js</a>
#     </li>
#     <li>
#         <a href=http://bokeh.pydata.org/en/latest/ > Python interactive visualization with Bokeh</a>
#     </li>
#
#     <li>
#         <a href=http://openlayers.org/>An opensource javascript library to load, display and render maps from multiple sources on web pages.</a>
#     </li>
#     <li>
#         <a href=https://github.com/rbgirshick/py-faster-rcnn> Faster R-CNN python implementation</a>
#     </li>
#     <li>
#         <a href=http://www.lifehack.org/articles/technology/40-key-computer-science-concepts-explained-laymans-terms.html>40 Computer Science Terms Explained</a>
#     </li>
#
#
#     <li>
#         <a href=http://igem.org/Main_Page> Synthetic Biology iGEM </a>
#     </li>
# </ul>
#
# <ul> Computational Neuroscience
#
#     <li>
#         <a href=http://neuralensemble.org> NeuralEnsemble is a community-based initiative to promote and co-ordinate open-source software development in neuroscience</a>
#     </li>
#
#     <li>
#         <a href=http://www.math.pitt.edu/~bard/xpp/xpp.html> X-windows PhasePlane plus Auto </a>
#     </li>
#
#     <li>
#         <a href=http://briansimulator.org/ > The Brian spiking neural network simulator - may be fun to build basal ganglia model</a>
#     </li>
# </ul>
#
# <ul> Editor/Shell:
#
#     <li>
#         <a href=http://www.howtogeek.com/115051/become-a-vi-master-by-learning-these-30-key-bindings/ > Learning top  vi key bindings</a>
#     </li>
#
#     <li>
#         <a href=https://github.com/emacs-tw/awesome-emacs#awesome-emacs> Awesome emacs </a>
#     </li>
#
#     <li>
#         <a href=http://www.jesshamrick.com/2012/09/10/absolute-beginners-guide-to-emacs/ > Absolute-beginners-guide-to-emacs</a>
#     </li>
#     <li>
#         <a href=http://lukaszwrobel.pl/blog/tmux-tutorial-split-terminal-windows-easily > Using TMUX</a>
#     </li>
#
#     <li>
#         <a href=http://blog.hawkhost.com/2010/06/28/tmux-the-terminal-multiplexer/ > Tmux - the terminal multiplexer </a>
#     </li>
#         <li>
#         <a href=https://github.com/emijrp/awesome-awesome> Awesome-awesomeness </a>
#     </li>
#         <li>
#         <a href=https://github.com/alebcay/awesome-shell> Awesome Shell </a>
#     </li>
#
# </ul>
#
# <ul> Stanford CS Core Curriculum
#     <li>
#         <a href=http://www.stanford.edu/class/cs106b/> CS106B - Programming Abstractions </a>
#     </li>
#     <li>
#         <a href=https://web.stanford.edu/class/cs107/> CS107 - Computer Organization & Systems </a>
#     </li>
#     <li>
#         <a href=http://web.stanford.edu/class/cs110/autumn-2016/> CS110 - Principles of Computer Systems>
#     </li>
#     <li>
#         <a href=http://web.stanford.edu/class/cs103/> CS103 - Mathematical Foundations of Computing>
#     </li>
#     <li>
#         <a href=http://web.stanford.edu/class/cs109/> CS109 - Intro to Probability for Computer Scientists>
#     </li>
#     <li>
#         <a href=http://web.stanford.edu/class/cs161/> CS161 - Data Structures and Algorithms>
#     </li>
# </ul>
#
# <ul> Important Papers:
#
#     <li>
#         <a href=http://news.harvard.edu/gazette/story/2015/10/closer-view-of-the-brain/ >Closer View of the Brain</a>
#     </li>
#     <li>
#         <a href=http://science.sciencemag.org.lprx.bates.edu/content/334/6056/618.full>The Big and the Small: Challenges of Imaging the Brain’s Circuits</a>
#     </li>
# </ul>
